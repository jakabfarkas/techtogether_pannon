# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
data = pd.read_excel('2_melleklet_EventLog_Pannon Egyetem.xlsx', index_col=None)

# %%
data = np.array(data)
            
for i in range(len(data)):
    for j in range(i+1, len(data)):
        if (i < len(data) and j < len(data) and
            data[i][0] == data[j][0] and
            data[i][4] == data[j][4] and
            data[i][5] == data[j][5] and
            data[i][6] == data[j][6]):
            data[i][1] += data[j][1]
            data[i][2] += data[j][2]
            data = np.delete(data, j, 0)

# %%
for i in range(len(data)):
    nok = nok + data[i][2]

# %%
workorders = []
op_cnt = []
time = []
n_ok = []
tech = []
work = []
us = []
for i in range(len(data)):
    if data[i][0] not in workorders:
        time_min = data[i][3]
        time_max = data[i][3]
        nok = 0
        cnt = 0
        technologies = []
        workplaces = []
        users = []
        for j in range(i, len(data)):
            if (data[j][0] == data[i][0]):
                if (data[j][3] < time_min):
                    time_min = data[j][3]
                if (data[j][3] > time_max):
                    time_max = data[j][3]
                nok = nok+data[j][2]
                cnt = cnt+1
                if (data[j][4] not in technologies):
                    technologies.append(data[j][4])
                if (data[j][5] not in workplaces):
                    workplaces.append(data[j][5])
                if (data[j][6] not in users):
                    users.append(data[j][6])
        print(data[i][0])
        workorders.append(data[i][0])
        print('   Operations: ', cnt)
        op_cnt.append(cnt)
        print('   Time from first to last: ', time_max-time_min)
        time.append((time_max-time_min).total_seconds())
        print('   NOK in all operations: ', nok)
        n_ok.append(nok)
        print('   Technologies: ', len(technologies))
        tech.append(len(technologies))
        print('   Workplaces: ', len(workplaces))
        work.append(len(workplaces))
        print('   Users: ', len(users))
        us.append(len(users))
        print('********************')
        
plt.bar(workorders, op_cnt, 1)
plt.xlabel('Workorders')
plt.ylabel('Operations')
plt.show()
plt.bar(workorders, time, 1)
plt.xlabel('Workorders')
plt.ylabel('Time from first to last')
plt.show()
plt.bar(workorders, n_ok, 1)
plt.xlabel('Workorders')
plt.ylabel('NOK')
plt.show()
plt.bar(workorders, tech, 1)
plt.xlabel('Workorders')
plt.ylabel('Technologies')
plt.show()
plt.bar(workorders, work, 1)
plt.xlabel('Workorders')
plt.ylabel('Workplaces')
plt.show()
plt.bar(workorders, us, 1)
plt.xlabel('Workorders')
plt.ylabel('Users')
plt.show()
# Out:
# Workorder 3
#    Operations:  9
#    Time from first to last:  2 days 07:10:43.363000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 4
#    Operations:  8
#    Time from first to last:  0 days 07:42:00.957000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  7
#    Users:  6
# ********************
# Workorder 5
#    Operations:  17
#    Time from first to last:  5 days 14:06:57.360000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  7
#    Users:  9
# ********************
# Workorder 6
#    Operations:  8
#    Time from first to last:  1 days 14:03:51.737000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 7
#    Operations:  7
#    Time from first to last:  1 days 02:44:06.543000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 8
#    Operations:  12
#    Time from first to last:  1 days 15:36:07.307000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  9
# ********************
# Workorder 9
#    Operations:  14
#    Time from first to last:  0 days 20:55:04.246000
#    NOK in all operations:  18
#    Technologies:  7
#    Workplaces:  5
#    Users:  9
# ********************
# Workorder 10
#    Operations:  12
#    Time from first to last:  0 days 13:11:31.583000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  7
#    Users:  11
# ********************
# Workorder 11
#    Operations:  10
#    Time from first to last:  0 days 09:25:39.740000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  8
#    Users:  7
# ********************
# Workorder 12
#    Operations:  16
#    Time from first to last:  0 days 23:06:32.093000
#    NOK in all operations:  6
#    Technologies:  8
#    Workplaces:  8
#    Users:  9
# ********************
# Workorder 13
#    Operations:  12
#    Time from first to last:  1 days 01:20:33.084000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 14
#    Operations:  10
#    Time from first to last:  1 days 03:28:49.376000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 15
#    Operations:  9
#    Time from first to last:  0 days 17:33:15.990000
#    NOK in all operations:  3
#    Technologies:  7
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 16
#    Operations:  7
#    Time from first to last:  1 days 01:47:54.330000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 17
#    Operations:  8
#    Time from first to last:  0 days 11:49:13.867000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 18
#    Operations:  8
#    Time from first to last:  0 days 18:03:06.993000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 19
#    Operations:  15
#    Time from first to last:  0 days 21:09:10.447000
#    NOK in all operations:  3
#    Technologies:  8
#    Workplaces:  7
#    Users:  8
# ********************
# Workorder 20
#    Operations:  8
#    Time from first to last:  4 days 09:47:46.463000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 21
#    Operations:  8
#    Time from first to last:  1 days 15:20:42.053000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 22
#    Operations:  13
#    Time from first to last:  3 days 14:29:41.490000
#    NOK in all operations:  30
#    Technologies:  6
#    Workplaces:  7
#    Users:  8
# ********************
# Workorder 23
#    Operations:  13
#    Time from first to last:  1 days 09:44:04.633000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 24
#    Operations:  7
#    Time from first to last:  3 days 14:34:10.006000
#    NOK in all operations:  33
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 25
#    Operations:  8
#    Time from first to last:  0 days 18:00:30.177000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 26
#    Operations:  14
#    Time from first to last:  0 days 14:31:27.867000
#    NOK in all operations:  0
#    Technologies:  9
#    Workplaces:  7
#    Users:  7
# ********************
# Workorder 27
#    Operations:  10
#    Time from first to last:  0 days 15:28:18.457000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 28
#    Operations:  11
#    Time from first to last:  2 days 09:35:47.873000
#    NOK in all operations:  3
#    Technologies:  7
#    Workplaces:  7
#    Users:  9
# ********************
# Workorder 29
#    Operations:  8
#    Time from first to last:  0 days 13:07:50.780000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 30
#    Operations:  6
#    Time from first to last:  0 days 10:40:11.573000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 31
#    Operations:  9
#    Time from first to last:  0 days 13:50:31.507000
#    NOK in all operations:  3
#    Technologies:  8
#    Workplaces:  7
#    Users:  6
# ********************
# Workorder 32
#    Operations:  14
#    Time from first to last:  0 days 14:27:09.513000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 33
#    Operations:  7
#    Time from first to last:  0 days 13:20:19.687000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 34
#    Operations:  10
#    Time from first to last:  3 days 13:12:15.934000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 35
#    Operations:  19
#    Time from first to last:  4 days 09:59:23.770000
#    NOK in all operations:  3
#    Technologies:  8
#    Workplaces:  7
#    Users:  10
# ********************
# Workorder 36
#    Operations:  5
#    Time from first to last:  2 days 16:55:55.354000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 37
#    Operations:  14
#    Time from first to last:  6 days 00:30:58.407000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 38
#    Operations:  11
#    Time from first to last:  3 days 23:14:22.020000
#    NOK in all operations:  9
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 39
#    Operations:  16
#    Time from first to last:  3 days 18:26:33.244000
#    NOK in all operations:  3
#    Technologies:  8
#    Workplaces:  7
#    Users:  9
# ********************
# Workorder 40
#    Operations:  10
#    Time from first to last:  5 days 21:47:12.744000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  7
#    Users:  7
# ********************
# Workorder 41
#    Operations:  12
#    Time from first to last:  3 days 05:40:13.206000
#    NOK in all operations:  3
#    Technologies:  7
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 42
#    Operations:  16
#    Time from first to last:  4 days 08:47:23.857000
#    NOK in all operations:  0
#    Technologies:  11
#    Workplaces:  7
#    Users:  9
# ********************
# Workorder 43
#    Operations:  6
#    Time from first to last:  0 days 16:46:56.313000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 44
#    Operations:  11
#    Time from first to last:  5 days 12:31:27.200000
#    NOK in all operations:  84
#    Technologies:  7
#    Workplaces:  8
#    Users:  8
# ********************
# Workorder 45
#    Operations:  11
#    Time from first to last:  0 days 15:18:12.423000
#    NOK in all operations:  0
#    Technologies:  9
#    Workplaces:  7
#    Users:  8
# ********************
# Workorder 46
#    Operations:  6
#    Time from first to last:  1 days 06:00:27.967000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 47
#    Operations:  7
#    Time from first to last:  2 days 04:07:52.463000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 48
#    Operations:  6
#    Time from first to last:  2 days 00:42:36.256000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 49
#    Operations:  14
#    Time from first to last:  1 days 06:15:54.056000
#    NOK in all operations:  3
#    Technologies:  9
#    Workplaces:  7
#    Users:  8
# ********************
# Workorder 50
#    Operations:  14
#    Time from first to last:  0 days 23:09:06.223000
#    NOK in all operations:  0
#    Technologies:  9
#    Workplaces:  8
#    Users:  9
# ********************
# Workorder 51
#    Operations:  8
#    Time from first to last:  0 days 14:06:49.057000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 52
#    Operations:  8
#    Time from first to last:  2 days 00:05:05.293000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  7
#    Users:  6
# ********************
# Workorder 53
#    Operations:  12
#    Time from first to last:  4 days 02:16:50.890000
#    NOK in all operations:  6
#    Technologies:  9
#    Workplaces:  7
#    Users:  5
# ********************
# Workorder 54
#    Operations:  9
#    Time from first to last:  0 days 17:01:01.887000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 55
#    Operations:  8
#    Time from first to last:  2 days 11:24:33.826000
#    NOK in all operations:  6
#    Technologies:  8
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 56
#    Operations:  19
#    Time from first to last:  1 days 01:51:48.610000
#    NOK in all operations:  0
#    Technologies:  9
#    Workplaces:  8
#    Users:  9
# ********************
# Workorder 58
#    Operations:  6
#    Time from first to last:  0 days 06:09:22.820000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 59
#    Operations:  10
#    Time from first to last:  0 days 18:48:33.287000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  7
#    Users:  8
# ********************
# Workorder 60
#    Operations:  9
#    Time from first to last:  2 days 19:03:34.974000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 61
#    Operations:  7
#    Time from first to last:  2 days 23:11:22.784000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 62
#    Operations:  7
#    Time from first to last:  5 days 15:44:01.400000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 63
#    Operations:  12
#    Time from first to last:  1 days 01:09:00.430000
#    NOK in all operations:  3
#    Technologies:  9
#    Workplaces:  7
#    Users:  9
# ********************
# Workorder 64
#    Operations:  6
#    Time from first to last:  0 days 22:37:48.027000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 65
#    Operations:  10
#    Time from first to last:  0 days 20:08:51.890000
#    NOK in all operations:  0
#    Technologies:  9
#    Workplaces:  7
#    Users:  7
# ********************
# Workorder 66
#    Operations:  8
#    Time from first to last:  2 days 13:24:32.906000
#    NOK in all operations:  6
#    Technologies:  7
#    Workplaces:  6
#    Users:  5
# ********************
# Workorder 67
#    Operations:  7
#    Time from first to last:  0 days 09:06:16.310000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 68
#    Operations:  8
#    Time from first to last:  2 days 09:49:28.593000
#    NOK in all operations:  3
#    Technologies:  7
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 69
#    Operations:  9
#    Time from first to last:  3 days 07:22:15.914000
#    NOK in all operations:  9
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 70
#    Operations:  7
#    Time from first to last:  0 days 13:55:07.850000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 71
#    Operations:  9
#    Time from first to last:  1 days 02:31:24.907000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 72
#    Operations:  9
#    Time from first to last:  1 days 02:01:49.866000
#    NOK in all operations:  51
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 73
#    Operations:  10
#    Time from first to last:  0 days 19:28:03.250000
#    NOK in all operations:  24
#    Technologies:  6
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 74
#    Operations:  11
#    Time from first to last:  1 days 04:46:53.190000
#    NOK in all operations:  12
#    Technologies:  6
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 75
#    Operations:  6
#    Time from first to last:  0 days 14:25:43.997000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  4
#    Users:  5
# ********************
# Workorder 76
#    Operations:  9
#    Time from first to last:  1 days 12:04:29.950000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 77
#    Operations:  9
#    Time from first to last:  2 days 13:32:34.720000
#    NOK in all operations:  12
#    Technologies:  7
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 78
#    Operations:  10
#    Time from first to last:  0 days 18:33:29.897000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 79
#    Operations:  7
#    Time from first to last:  0 days 09:16:02.767000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 80
#    Operations:  7
#    Time from first to last:  0 days 11:28:29.490000
#    NOK in all operations:  9
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 81
#    Operations:  10
#    Time from first to last:  0 days 13:58:26.110000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 82
#    Operations:  10
#    Time from first to last:  0 days 17:52:39.560000
#    NOK in all operations:  9
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 83
#    Operations:  6
#    Time from first to last:  0 days 06:30:02.106000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 84
#    Operations:  8
#    Time from first to last:  0 days 10:43:09.797000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 85
#    Operations:  11
#    Time from first to last:  0 days 12:26:00.594000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 86
#    Operations:  6
#    Time from first to last:  0 days 23:38:28.390000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 87
#    Operations:  7
#    Time from first to last:  0 days 17:53:17.800000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 88
#    Operations:  9
#    Time from first to last:  0 days 12:03:23.450000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 89
#    Operations:  9
#    Time from first to last:  2 days 13:42:16.497000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 90
#    Operations:  6
#    Time from first to last:  2 days 17:21:07.477000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  3
# ********************
# Workorder 91
#    Operations:  13
#    Time from first to last:  2 days 21:35:30.237000
#    NOK in all operations:  3
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 92
#    Operations:  16
#    Time from first to last:  0 days 22:29:39.910000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  11
# ********************
# Workorder 93
#    Operations:  13
#    Time from first to last:  1 days 06:27:18.413000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 94
#    Operations:  10
#    Time from first to last:  0 days 18:54:19.490000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 95
#    Operations:  8
#    Time from first to last:  0 days 13:19:00.474000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 96
#    Operations:  7
#    Time from first to last:  3 days 13:57:58.444000
#    NOK in all operations:  36
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 97
#    Operations:  9
#    Time from first to last:  4 days 20:18:12.033000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 98
#    Operations:  11
#    Time from first to last:  0 days 13:17:14.716000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 99
#    Operations:  11
#    Time from first to last:  0 days 17:29:31.294000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 100
#    Operations:  9
#    Time from first to last:  0 days 21:20:58.510000
#    NOK in all operations:  6
#    Technologies:  7
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 101
#    Operations:  12
#    Time from first to last:  5 days 16:49:41.557000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 102
#    Operations:  8
#    Time from first to last:  0 days 22:36:31.010000
#    NOK in all operations:  96
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 103
#    Operations:  8
#    Time from first to last:  0 days 08:52:48.360000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 104
#    Operations:  10
#    Time from first to last:  0 days 17:41:44.306000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 105
#    Operations:  8
#    Time from first to last:  1 days 06:16:26.720000
#    NOK in all operations:  12
#    Technologies:  5
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 106
#    Operations:  11
#    Time from first to last:  0 days 14:56:58.600000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 107
#    Operations:  12
#    Time from first to last:  0 days 10:00:18.380000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  8
# ********************
# Workorder 108
#    Operations:  7
#    Time from first to last:  1 days 01:56:41.893000
#    NOK in all operations:  12
#    Technologies:  6
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 109
#    Operations:  8
#    Time from first to last:  0 days 05:50:25.760000
#    NOK in all operations:  0
#    Technologies:  7
#    Workplaces:  6
#    Users:  4
# ********************
# Workorder 110
#    Operations:  11
#    Time from first to last:  0 days 12:54:12.857000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 111
#    Operations:  5
#    Time from first to last:  0 days 07:30:06.077000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 112
#    Operations:  5
#    Time from first to last:  0 days 05:22:54.020000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  3
# ********************
# Workorder 113
#    Operations:  7
#    Time from first to last:  1 days 09:35:11.397000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 114
#    Operations:  9
#    Time from first to last:  1 days 01:39:10.247000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 115
#    Operations:  12
#    Time from first to last:  0 days 21:47:56.700000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 116
#    Operations:  8
#    Time from first to last:  0 days 21:33:32.686000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 117
#    Operations:  10
#    Time from first to last:  3 days 07:54:26.890000
#    NOK in all operations:  39
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 118
#    Operations:  8
#    Time from first to last:  3 days 01:57:58.817000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 119
#    Operations:  13
#    Time from first to last:  3 days 07:27:38.713000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 120
#    Operations:  6
#    Time from first to last:  2 days 23:48:55.293000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 121
#    Operations:  12
#    Time from first to last:  0 days 17:56:48.950000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 122
#    Operations:  7
#    Time from first to last:  2 days 20:44:11.364000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 123
#    Operations:  7
#    Time from first to last:  0 days 13:57:08.773000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 124
#    Operations:  8
#    Time from first to last:  3 days 01:37:51.347000
#    NOK in all operations:  21
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 125
#    Operations:  10
#    Time from first to last:  0 days 22:06:49.957000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 126
#    Operations:  8
#    Time from first to last:  0 days 22:27:01.193000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 127
#    Operations:  6
#    Time from first to last:  0 days 19:27:09.370000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 128
#    Operations:  7
#    Time from first to last:  0 days 20:05:46.440000
#    NOK in all operations:  9
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 129
#    Operations:  10
#    Time from first to last:  3 days 19:09:25.220000
#    NOK in all operations:  12
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 130
#    Operations:  10
#    Time from first to last:  1 days 01:51:13.900000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 131
#    Operations:  11
#    Time from first to last:  0 days 13:43:33.776000
#    NOK in all operations:  51
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 132
#    Operations:  10
#    Time from first to last:  0 days 17:27:26.866000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 133
#    Operations:  11
#    Time from first to last:  0 days 23:44:58.187000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 134
#    Operations:  5
#    Time from first to last:  0 days 12:47:23.796000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  4
# ********************
# Workorder 135
#    Operations:  20
#    Time from first to last:  0 days 22:19:37.800000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  8
# ********************
# Workorder 136
#    Operations:  6
#    Time from first to last:  1 days 05:09:04.546000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  3
# ********************
# Workorder 137
#    Operations:  9
#    Time from first to last:  0 days 17:46:33.393000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 138
#    Operations:  5
#    Time from first to last:  0 days 18:59:24.530000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 139
#    Operations:  9
#    Time from first to last:  0 days 14:26:49.666000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 140
#    Operations:  5
#    Time from first to last:  0 days 08:48:49.443000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 141
#    Operations:  7
#    Time from first to last:  0 days 10:43:28.443000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 142
#    Operations:  6
#    Time from first to last:  0 days 22:04:30.010000
#    NOK in all operations:  6
#    Technologies:  6
#    Workplaces:  4
#    Users:  3
# ********************
# Workorder 143
#    Operations:  9
#    Time from first to last:  0 days 11:54:14.983000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 144
#    Operations:  6
#    Time from first to last:  0 days 10:17:36.253000
#    NOK in all operations:  9
#    Technologies:  6
#    Workplaces:  5
#    Users:  3
# ********************
# Workorder 145
#    Operations:  5
#    Time from first to last:  0 days 19:03:48.500000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  4
#    Users:  3
# ********************
# Workorder 146
#    Operations:  6
#    Time from first to last:  1 days 10:08:30.663000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  4
#    Users:  5
# ********************
# Workorder 147
#    Operations:  6
#    Time from first to last:  0 days 20:50:43.423000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 148
#    Operations:  7
#    Time from first to last:  0 days 13:47:12.224000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  4
#    Users:  4
# ********************
# Workorder 149
#    Operations:  10
#    Time from first to last:  1 days 08:53:45.294000
#    NOK in all operations:  9
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 150
#    Operations:  13
#    Time from first to last:  1 days 01:42:20.836000
#    NOK in all operations:  6
#    Technologies:  8
#    Workplaces:  6
#    Users:  6
# ********************
# Workorder 151
#    Operations:  8
#    Time from first to last:  0 days 10:25:28.404000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 152
#    Operations:  8
#    Time from first to last:  1 days 04:13:40.847000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 153
#    Operations:  9
#    Time from first to last:  1 days 07:04:07.323000
#    NOK in all operations:  15
#    Technologies:  5
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 154
#    Operations:  12
#    Time from first to last:  2 days 23:43:22.777000
#    NOK in all operations:  3
#    Technologies:  6
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 155
#    Operations:  6
#    Time from first to last:  2 days 14:02:41.330000
#    NOK in all operations:  0
#    Technologies:  5
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 156
#    Operations:  7
#    Time from first to last:  2 days 14:58:58.053000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  5
# ********************
# Workorder 157
#    Operations:  9
#    Time from first to last:  2 days 18:02:13.823000
#    NOK in all operations:  3
#    Technologies:  5
#    Workplaces:  5
#    Users:  7
# ********************
# Workorder 158
#    Operations:  12
#    Time from first to last:  3 days 05:00:05.220000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 159
#    Operations:  9
#    Time from first to last:  2 days 15:12:22.360000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 160
#    Operations:  8
#    Time from first to last:  0 days 09:51:38.683000
#    NOK in all operations:  3
#    Technologies:  7
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 161
#    Operations:  10
#    Time from first to last:  3 days 09:00:24.977000
#    NOK in all operations:  0
#    Technologies:  8
#    Workplaces:  6
#    Users:  7
# ********************
# Workorder 162
#    Operations:  8
#    Time from first to last:  0 days 12:16:54.300000
#    NOK in all operations:  0
#    Technologies:  6
#    Workplaces:  5
#    Users:  6
# ********************
# Workorder 163
#    Operations:  6
#    Time from first to last:  5 days 19:04:08.300000
#    NOK in all operations:  6
#    Technologies:  5
#    Workplaces:  3
#    Users:  4
# ********************
# Workorder 164
#    Operations:  10
#    Time from first to last:  0 days 12:00:44.400000
#    NOK in all operations:  12
#    Technologies:  6
#    Workplaces:  4
#    Users:  6
# ********************
# Workorder 165
#    Operations:  8
#    Time from first to last:  0 days 10:52:09.550000
#    NOK in all operations:  27
#    Technologies:  5
#    Workplaces:  4
#    Users:  6
# ********************
# Workorder 166
#    Operations:  2
#    Time from first to last:  0 days 08:59:16.400000
#    NOK in all operations:  0
#    Technologies:  1
#    Workplaces:  1
#    Users:  2
# ********************
# Workorder 167
#    Operations:  3
#    Time from first to last:  0 days 00:33:13.230000
#    NOK in all operations:  24
#    Technologies:  2
#    Workplaces:  1
#    Users:  2
# ********************
# Workorder 168
#    Operations:  9
#    Time from first to last:  0 days 11:52:29.737000
#    NOK in all operations:  0
#    Technologies:  4
#    Workplaces:  4
#    Users:  6
# ********************
# Workorder 169
#    Operations:  4
#    Time from first to last:  0 days 04:44:47.843000
#    NOK in all operations:  3
#    Technologies:  3
#    Workplaces:  3
#    Users:  3
# ********************

# %%
technologies = []
op_cnt = []
n_ok = []
order = []
place = []
us = []
for i in range(len(data)):
    if data[i][4] not in technologies:
        nok = 0
        cnt = 0
        workorders = []
        workplaces = []
        users = []
        for j in range(0, len(data)):
            if (data[j][4] == data[i][4]):
                nok = nok+data[j][2]
                cnt = cnt+1
                if (data[j][0] not in workorders):
                    workorders.append(data[j][0])
                if (data[j][5] not in workplaces):
                    workplaces.append(data[j][5])
                if (data[j][6] not in users):
                    users.append(data[j][6])
        print(data[i][4])
        technologies.append(data[i][4])
        print('   Operations: ', cnt)
        op_cnt.append(cnt)
        print('   NOK: ', nok)
        n_ok.append(nok)
        print('   Workorders: ', len(workorders))
        order.append(len(workorders))
        print('   Workplaces: ', len(workplaces))
        place.append(len(workplaces))
        print('   Users: ', len(users))
        us.append(len(users))
        print('********************')
        
plt.bar(technologies, op_cnt, 1)
plt.xlabel('Technologies')
plt.ylabel('Operations')
plt.xticks(rotation='vertical')
plt.show()
plt.bar(technologies, n_ok, 1)
plt.xlabel('Technologies')
plt.ylabel('NOK')
plt.xticks(rotation='vertical')
plt.show()
plt.bar(technologies, order, 1)
plt.xlabel('Technologies')
plt.ylabel('Workorders')
plt.xticks(rotation='vertical')
plt.show()
plt.bar(technologies, place, 1)
plt.xlabel('Technologies')
plt.ylabel('Workplaces')
plt.xticks(rotation='vertical')
plt.show()
plt.bar(technologies, us, 1)
plt.xlabel('Technologies')
plt.ylabel('Users')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# Vágás
#    Operations:  35
#    NOK:  3
#    Workorders:  25
#    Workplaces:  2
#    Users:  16
# ********************
# Furat 1
#    Operations:  24
#    NOK:  6
#    Workorders:  17
#    Workplaces:  2
#    Users:  13
# ********************
# Furat 2
#    Operations:  83
#    NOK:  30
#    Workorders:  45
#    Workplaces:  4
#    Users:  16
# ********************
# Csomagolás
#    Operations:  218
#    NOK:  93
#    Workorders:  159
#    Workplaces:  3
#    Users:  20
# ********************
# Marás 1
#    Operations:  44
#    NOK:  15
#    Workorders:  32
#    Workplaces:  2
#    Users:  13
# ********************
# Marás 2
#    Operations:  26
#    NOK:  30
#    Workorders:  14
#    Workplaces:  4
#    Users:  10
# ********************
# Furat 3
#    Operations:  15
#    NOK:  6
#    Workorders:  8
#    Workplaces:  3
#    Users:  11
# ********************
# Marás 3
#    Operations:  60
#    NOK:  18
#    Workorders:  43
#    Workplaces:  6
#    Users:  14
# ********************
# Furat 4
#    Operations:  236
#    NOK:  129
#    Workorders:  164
#    Workplaces:  5
#    Users:  17
# ********************
# Furat 5
#    Operations:  197
#    NOK:  18
#    Workorders:  145
#    Workplaces:  3
#    Users:  14
# ********************
# Furat 6
#    Operations:  25
#    NOK:  9
#    Workorders:  13
#    Workplaces:  3
#    Users:  11
# ********************
# Furat 7
#    Operations:  3
#    NOK:  0
#    Workorders:  3
#    Workplaces:  2
#    Users:  3
# ********************
# Furat 8
#    Operations:  33
#    NOK:  3
#    Workorders:  18
#    Workplaces:  3
#    Users:  8
# ********************
# Addicionális művelet
#    Operations:  5
#    NOK:  0
#    Workorders:  5
#    Workplaces:  2
#    Users:  4
# ********************
# Furat 9
#    Operations:  238
#    NOK:  81
#    Workorders:  163
#    Workplaces:  2
#    Users:  21
# ********************
# Megmunkálás
#    Operations:  287
#    NOK:  510
#    Workorders:  166
#    Workplaces:  5
#    Users:  10
# ********************

# %%
workplaces = []
for i in range(len(data)):
    if data[i][5] not in workplaces:
        workplaces.append(data[i][5])
        nok = 0
        cnt = 0
        workorders = []
        technologies = []
        users = []
        for j in range(0, len(data)):
            if (data[j][5] == data[i][5]):
                nok = nok+data[j][2]
                cnt = cnt+1
                if (data[j][0] not in workorders):
                    workorders.append(data[j][0])
                if (data[j][4] not in technologies):
                    technologies.append(data[j][4])
                if (data[j][6] not in users):
                    users.append(data[j][6])
        print(data[i][5])
        print('   Operations: ', cnt)
        print('   NOK: ', nok)
        print('   Workorders: ', len(workorders))
        print('   Technologies: ', len(technologies))
        print('   Users: ', len(users))
        print('********************')
# Out:
# Machine 1
#    Operations:  97
#    NOK in all operations:  3
#    Workorders:  97
#    Technologies:  15
#    Users:  22
# ********************
# Machine 2
#    Operations:  34
#    NOK in all operations:  6
#    Workorders:  34
#    Technologies:  6
#    Users:  12
# ********************
# Packaging 1
#    Operations:  20
#    NOK in all operations:  3
#    Workorders:  20
#    Technologies:  1
#    Users:  8
# ********************
# Packaging 2
#    Operations:  183
#    NOK in all operations:  90
#    Workorders:  183
#    Technologies:  1
#    Users:  17
# ********************
# Machine 3
#    Operations:  62
#    NOK in all operations:  15
#    Workorders:  62
#    Technologies:  3
#    Users:  15
# ********************
# Machine 4
#    Operations:  87
#    NOK in all operations:  102
#    Workorders:  87
#    Technologies:  4
#    Users:  7
# ********************
# Machine 5
#    Operations:  37
#    NOK in all operations:  39
#    Workorders:  37
#    Technologies:  3
#    Users:  6
# ********************
# Machine 6
#    Operations:  139
#    NOK in all operations:  111
#    Workorders:  139
#    Technologies:  7
#    Users:  7
# ********************
# Machine 7
#    Operations:  132
#    NOK in all operations:  60
#    Workorders:  132
#    Technologies:  5
#    Users:  9
# ********************
# Machine 8
#    Operations:  74
#    NOK in all operations:  294
#    Workorders:  74
#    Technologies:  1
#    Users:  9
# ********************
# Machine 9
#    Operations:  224
#    NOK in all operations:  126
#    Workorders:  224
#    Technologies:  1
#    Users:  13
# ********************
# Machine 10
#    Operations:  237
#    NOK in all operations:  81
#    Workorders:  237
#    Technologies:  2
#    Users:  21
# ********************
# Robot
#    Operations:  203
#    NOK in all operations:  21
#    Workorders:  203
#    Technologies:  2
#    Users:  10
# ********************

# %%
users = []
for i in range(len(data)):
    if data[i][6] not in users:
        users.append(data[i][6])
        nok = 0
        cnt = 0
        workorders = []
        technologies = []
        workplaces = []
        for j in range(0, len(data)):
            if (data[j][6] == data[i][6]):
                nok = nok+data[j][2]
                cnt = cnt+1
                if (data[j][0] not in workorders):
                    workorders.append(data[j][0])
                if (data[j][4] not in technologies):
                    technologies.append(data[j][4])
                if (data[j][5] not in workplaces):
                    workplaces.append(data[j][5])
        print(data[i][6])
        print('   Operations: ', cnt)
        print('   NOK: ', nok)
        print('   Workorders: ', len(workorders))
        print('   Technologies: ', len(technologies))
        print('   Workplaces: ', len(workplaces))
        print('********************')
# Out:
# Operator 2
#    Operations:  90
#    NOK:  6
#    Workorders:  57
#    Technologies:  7
#    Workplaces:  7
# ********************
# Operator 3
#    Operations:  27
#    NOK:  3
#    Workorders:  17
#    Technologies:  7
#    Workplaces:  6
# ********************
# Operator 4
#    Operations:  111
#    NOK:  45
#    Workorders:  66
#    Technologies:  8
#    Workplaces:  6
# ********************
# Operator 5
#    Operations:  10
#    NOK:  0
#    Workorders:  5
#    Technologies:  6
#    Workplaces:  1
# ********************
# Operator 6
#    Operations:  147
#    NOK:  108
#    Workorders:  87
#    Technologies:  10
#    Workplaces:  7
# ********************
# Operator 7
#    Operations:  74
#    NOK:  0
#    Workorders:  45
#    Technologies:  11
#    Workplaces:  7
# ********************
# Operator 8
#    Operations:  29
#    NOK:  6
#    Workorders:  20
#    Technologies:  11
#    Workplaces:  5
# ********************
# Operator 9
#    Operations:  6
#    NOK:  0
#    Workorders:  5
#    Technologies:  5
#    Workplaces:  4
# ********************
# Operator 10
#    Operations:  82
#    NOK:  204
#    Workorders:  64
#    Technologies:  13
#    Workplaces:  10
# ********************
# Operator 11
#    Operations:  132
#    NOK:  36
#    Workorders:  83
#    Technologies:  8
#    Workplaces:  7
# ********************
# Operator 12
#    Operations:  32
#    NOK:  6
#    Workorders:  21
#    Technologies:  9
#    Workplaces:  6
# ********************
# Operator 13
#    Operations:  105
#    NOK:  12
#    Workorders:  64
#    Technologies:  6
#    Workplaces:  8
# ********************
# Operator 14
#    Operations:  67
#    NOK:  66
#    Workorders:  46
#    Technologies:  12
#    Workplaces:  9
# ********************
# Operator 15
#    Operations:  93
#    NOK:  12
#    Workorders:  63
#    Technologies:  11
#    Workplaces:  8
# ********************
# Operator 16
#    Operations:  10
#    NOK:  0
#    Workorders:  7
#    Technologies:  5
#    Workplaces:  4
# ********************
# Operator 17
#    Operations:  56
#    NOK:  27
#    Workorders:  43
#    Technologies:  10
#    Workplaces:  11
# ********************
# Operator 18
#    Operations:  96
#    NOK:  87
#    Workorders:  66
#    Technologies:  13
#    Workplaces:  11
# ********************
# Operator 19
#    Operations:  12
#    NOK:  0
#    Workorders:  10
#    Technologies:  4
#    Workplaces:  4
# ********************
# Operator 20
#    Operations:  2
#    NOK:  0
#    Workorders:  2
#    Technologies:  2
#    Workplaces:  2
# ********************
# Operator 21
#    Operations:  7
#    NOK:  0
#    Workorders:  6
#    Technologies:  3
#    Workplaces:  3
# ********************
# Operator 22
#    Operations:  68
#    NOK:  156
#    Workorders:  56
#    Technologies:  8
#    Workplaces:  5
# ********************
# Operator 23
#    Operations:  3
#    NOK:  0
#    Workorders:  3
#    Technologies:  3
#    Workplaces:  3
# ********************
# Operator 24
#    Operations:  88
#    NOK:  36
#    Workorders:  64
#    Technologies:  10
#    Workplaces:  8
# ********************
# Operator 25
#    Operations:  85
#    NOK:  87
#    Workorders:  63
#    Technologies:  9
#    Workplaces:  8
# ********************
# Operator 26
#    Operations:  7
#    NOK:  0
#    Workorders:  6
#    Technologies:  2
#    Workplaces:  2
# ********************
# Operator 27
#    Operations:  90
#    NOK:  54
#    Workorders:  61
#    Technologies:  8
#    Workplaces:  4
# ********************
